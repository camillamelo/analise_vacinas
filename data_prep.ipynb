# %% [markdown]
# <a href="https://colab.research.google.com/github/camillamelo/analise_vacinas/blob/main/data_prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
source_file = '/content/drive/MyDrive/Colab Notebooks/Vacina/Raw/tweets_vacina.csv'
save_file = '/content/drive/MyDrive/Colab Notebooks/Vacina/Processed/tweets_vacina.parquet'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Leitura dos Dados

# %%
data = pandas.read_csv(source_file, sep=',', index_col=0)

print('shape:', data.shape)
print('columns:', data.columns)
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# shape: (1995384, 35)
# columns: Index(['conversation_id', 'created_at', 'date', 'time', 'timezone', 'user_id',
#        'username', 'name', 'place', 'tweet', 'language', 'mentions', 'urls',
#        'photos', 'replies_count', 'retweets_count', 'likes_count', 'hashtags',
#        'cashtags', 'link', 'retweet', 'quote_url', 'video', 'thumbnail',
#        'near', 'geo', 'source', 'user_rt_id', 'user_rt', 'retweet_id',
#        'reply_to', 'retweet_date', 'translate', 'trans_src', 'trans_dest'],
#       dtype='object')
#                          conversation_id  ... trans_dest
# id                                        ...
# 1356029459929903104  1355512142540242946  ...        NaN
# 1356029449570054145  1356024186041458689  ...        NaN
# 1356029447116349447  1356024875941588997  ...        NaN
# 1356029439138811904  1351551195421286403  ...        NaN
# 1356029421954727938  1356029421954727938  ...        NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Remove colunas desnecessárias

# %%
data.drop("created_at", axis=1, inplace=True)
data.drop("username", axis=1, inplace=True)
data.drop("name", axis=1, inplace=True)
data.drop("place", axis=1, inplace=True)
data.drop("geo", axis=1, inplace=True)
data.drop("source", axis=1, inplace=True)
data.drop("user_rt_id", axis=1, inplace=True)
data.drop("user_rt", axis=1, inplace=True)
data.drop("retweet_id", axis=1, inplace=True)
data.drop("retweet", axis=1, inplace=True)
data.drop("retweet_date", axis=1, inplace=True)
data.drop("reply_to", axis=1, inplace=True)
data.drop("translate", axis=1, inplace=True)
data.drop("trans_src", axis=1, inplace=True)
data.drop("trans_dest", axis=1, inplace=True)
data.drop("photos", axis=1, inplace=True)
data.drop("video", axis=1, inplace=True)
data.drop("near", axis=1, inplace=True)
print('shape:', data.shape)
data.head()
# Out:
# shape: (1995384, 17)
#                          conversation_id        date  ... quote_url  thumbnail
# id                                                    ...
# 1356029459929903104  1355512142540242946  2021-01-31  ...       NaN        NaN
# 1356029449570054145  1356024186041458689  2021-01-31  ...       NaN        NaN
# 1356029447116349447  1356024875941588997  2021-01-31  ...       NaN        NaN
# 1356029439138811904  1351551195421286403  2021-01-31  ...       NaN        NaN
# 1356029421954727938  1356029421954727938  2021-01-31  ...       NaN        NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Remove linhas que não mencionam "vacina"

# %%
df_filtered = data[data.tweet.str.contains('vacina')] 
print('shape:', df_filtered.shape)
df_filtered.head()
# Out:
# shape: (1841476, 17)
#                          conversation_id        date  ... quote_url  thumbnail
# id                                                    ...
# 1356029459929903104  1355512142540242946  2021-01-31  ...       NaN        NaN
# 1356029449570054145  1356024186041458689  2021-01-31  ...       NaN        NaN
# 1356029447116349447  1356024875941588997  2021-01-31  ...       NaN        NaN
# 1356029439138811904  1351551195421286403  2021-01-31  ...       NaN        NaN
# 1356029421954727938  1356029421954727938  2021-01-31  ...       NaN        NaN
#
# [5 rows x 17 columns]

# %%
df_filtered.to_parquet(save_file)
